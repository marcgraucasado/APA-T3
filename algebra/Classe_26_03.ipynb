# %%
class ClaseUno:
    """
    Clase para probar cosas de Python
    """

    atributo = 17
    
    #metodos
    def metodo_suma(mi_mismo, x, y):
        return x + y

# %%
ClaseUno.atributo
# Out:
# 17

# %%
ClaseUno()

# %%
objeto_uno = ClaseUno()

# %%
objeto_uno.atributo
# Out:
# 17

# %%
objeto_uno.metodo_suma(4. ,45)
# Out:
# 49.0

# %%
def suma(_, x, y):
    """
    Suma psicodelica
    """

    return x - y

# %%
objeto_uno.metodo_suma(3, 6)
# Out:
# 9

# %%
objeto_uno.metodo_suma = suma

# %%
objeto_uno.metodo_suma(_, 5, 3)
# Out:
# 2

# %%
objeto_uno = ClaseUno()

# %%
objeto_uno.atributo
# Out:
# 17

# %%
objeto_II = ClaseUno()

# %%
objeto_II.atributo
# Out:
# 17

# %%
objeto_II.atributo = 76

# %%
ClaseUno.atributo = 69

# %%
mkdir algebra

# %%
v1 = [2, 4, 6]
v2 = [1, 3, 5]
v1 + v2
# Out:
# [2, 4, 6, 1, 3, 5]

# %%
run algebra/vectores.py

# %%
v = Vector([2, 4, 6, 8])

# %%
dir(v)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'vector']

# %%
v.vector
# Out:
# [2, 4, 6, 8]

# %%
a = 33

# %%
a
# Out:
# 33

# %%
v

# %%
cd algebra
# Out:
# /Users/markituus/Desktop/APA-T2/algebra

# %%
# %run vectores.py

# %%
v = Vector([2, 4, 6])

# %%
v
# Out:
# Vector([2, 4, 6])

# %%
print(v)
# Out:
# Vector([2, 4, 6])
